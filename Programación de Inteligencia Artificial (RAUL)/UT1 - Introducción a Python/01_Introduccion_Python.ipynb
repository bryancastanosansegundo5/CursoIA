# %% [markdown]
# <table style="width: 100%; border: 0; border-bottom: 2px solid #1f5a7a; margin-bottom: 24px;">
#   <tr>
#     <td style="border: 0; text-align: left; padding-bottom: 12px;">
#       <strong style="font-size: 1.25em;">Programación de Inteligencia Artificial</strong><br>
#       <em>Curso de Especialización de IA y Big Data</em><br><br>
#       Raúl Rubio Vázquez
#     </td>
#     <td style="border: 0; text-align: right; vertical-align: middle; padding-bottom: 12px;">
#       <img src="img/logo_claudio.jpg" alt="Logotipo" width="82">
#     </td>
#   </tr>
# </table>

# %% [markdown]
# ***
#
# <h1 align="center">01 - Introducción a Python</h1>
#
# ***

# %% [markdown]
# ## Objetivos
# - Preparar el entorno de trabajo
# - Conocer las diferentes herramientas
# - Sintaxis básica de Python

# %% [markdown]
# ## 1.Preparar el entorno de trabajo
#
# Cuando comenzamos a trabajar con cualquier lenguaje de programación, lo primero que necesitamos es un compilador de dicho lenguaje y una herramienta para escribir código. Si esa herramienta es un IDE, mucho mejor.
#
# En el caso de __Python__, ese _compilador_ será el __intérprete de Python__ (recordemos que Python es un lenguaje interpretado, no compilado). En cuanto al IDE, existen múltiples opciones, siendo las más habituales __VSCode__ y __PyCharm__. Además, __Python__ es un lenguaje cuya principal fortaleza son los múltiples módulos que pueden encontrarse para agilizar cualquier desarrollo, por lo que no solo será interesante contar con el intérprete, sino también con su gestor de módulos __pip__.

# %% [markdown]
# ### 1.1. Instalar Python
# Hay muchas maneras de gestionar la instalación de Python dependiendo del sistema operativo.
#
# - __Windows__: Instalador oficial, Microsoft Store, WSL, Conda
#
# - __GNU/Linux__: Gestor de paquetes de la distribución, Pyenv, Desde fuentes, Conda
#
# - __macOS__: Instalador oficial, Pyenv, Hombebrew, Desde fuentes, Conda
#
# Según nos decantemos por uno u otro tipo de instalación tendremos más control sobre qué versión instalamos y dónde lo hacemos, pero para lo que nos ocupa como recién embarcados en esta aventura, todas las opciones nos resultan válidas. Sin embargo, en aras de la simplicidad, recurriremos a la última, que vemos que se repite en todos los sistemas.
#
# #### CONDA o ANACONDA. Esto va de serpientes
#
# Conda es un gestor de paquetes y entornos para Python, ideal para un entorno de aprendizaje como el nuestro y, en concreto, Anaconda es un empaquetado que incluye, además de Conda, cientos de paquetes para trabajar en Análisis de datos (_Data Science_) y Aprendizaje automático (_Machine Learning_), como __Numpy__, __Pandas__, __Matplotlib__, __Scikit-Learn__ o la aplicacion __Jupyter Notebooks__, que es con la que se han realizado estos apuntes.
#
# Podéis encontrar documentación sobre como llevar a cabo la instalación y su uso en:
#
# - http://docs.anaconda.com/anaconda/install/
# - https://docs.anaconda.com/anaconda/user-guide/getting-started
#
# Una vez instalado Anaconda, tendrá un aspecto similar al de la imagen:
#
# ![Interfaz de Anaconda Navigator](attachment:3db0c448-81d7-4485-a437-4aeb8ed237d7.jpg)

# %% [markdown]
# ### 1.2. Ejecutar Python
# Para ejecutar el intérprete de Python abriremos la terminal de nuestro sistema operativo y ejecutaremos el siguiente comando:
#
# - __Windows__: `python`
# - __GNU/Linux__ y __macOS__: `python3`_(o `python` si hay un alias creado)_
#
# Para asegurarnos de que estamos utilizando la versión de Python que hemos instalado con Anaconda y evitar problemas posteriores, lo podemos comprobar del siguiente modo:
#
# - __Windows__: `where python`
# - __GNU/Linux__ y __macOS__: `which python3`

# %% [markdown]
# ### 1.3. Instalación de paquetes
# Como hemos dicho, una de las principales fortalezas de python es la ingente cantidad de módulos existente para cualquier propósito, la cual podemos consultar en [Pypi](https://pypi.org). Python nos provee de una utilidad para instalar paquetes: `pip`mediante la sentencia: `pip install nombre_paquete`.
#
# No obstante, nosotros usaremos Anaconda para tal efecto. Para ello iremos a la pestaña __Enviroments__ _(Entornos)_ y ahi nos aparecerá el entorno _base (root)_ y los paquetes instalados. Como vemos, Anaconda se ha encargado de instalar muchos paquetes por nosotros. Si queremos instalar un paquete, bastará con seleccionar en el desplegable _Not installed_, escribir el nombre del paquete que queremos instalar, marcar el check del paquete y darle a aplicar los cambios.
#
# ![Sección de Entornos Virtuales](attachment:2ff24717-d025-45df-8160-4883c3007501.jpg)

# %% [markdown]
# ### 1.4. Entornos Virtuales
# Como habréis observado, la pestaña __Enviroments__ nos permite crear nuevos entornos. ¿En qué consiste esto? Imaginad que estamos trabajando en un proyecto que utiliza la última versión de python y varios paquetes actualizados a su última versión. Ahora nos pasan otro proyecto para que solucionemos algunos fallos o añadamos alguna funcionalidad, pero ese proyecto utiliza una versión anterior de python o de las bibliotecas. Si bajamos la versión de nuestro intérprete de python o de las bibliotecas, podremos trabajar en el proyecto recién llegado, pero ya no serán compatibles con el otro proyecto en el que estábamos. Para solucionar esto, python nos permite crear entornos virtuales.
#
# Mediante el uso de entornos virtuales podemos tener distintas versiones de python o de los paquetes para cada entorno y, para hacer uso de ellos, bastará con cambiar de un entorno a otro. Python nos provee del módulo `venv` para crear entornos virtuales y, además, existen otras utilidades más completas como `pipenv`o `poetry`. En la siguiente tabla podemos ver una comparativa entre ellos:
#
# | Característica | **venv** (Estándar) | **pipenv** | **poetry** |
# | :--- | :--- | :--- | :--- |
# | **Gestión de Entornos** | Manual (`python -m venv`) | Automática (se crea al instalar) | Automática (se crea al instalar) |
# | **Gestión de Dependencias** | Manual (`pip install`) | Automática (gestiona versiones) | Automática (gestiona versiones y resolución) |
# | **Archivo de Configuración** | `requirements.txt` (lista plana) | `Pipfile` + `Pipfile.lock` | `pyproject.toml` + `poetry.lock` |
# | **Bloqueo de Versiones (Lock)** | ❌ No (manual) | ✅ Sí (`Pipfile.lock`) | ✅ Sí (`poetry.lock`) |
# | **Resolución de Dependencias** | ❌ No (puede haber conflictos) | ✅ Sí (búsqueda inteligente) | ✅ Sí (algoritmo más robusto) |
# | **Gestión de Python** | ❌ No (requiere Python instalado) | ❌ No (requiere Python instalado) | ❌ No nativamente (pero se integra con pyenv) |
# | **Reproducibilidad** | ❌ Baja (versiones flotantes) | ✅ Alta | ✅ Muy Alta |
# | **Velocidad** | Muy rápida | Lenta (resolución lenta) | Moderada  |
# | **Curva de Aprendizaje** | Baja (básico) | Media (concepto de Pipfile) | Media (pyproject.toml) |
# | **Adopción en la Industria** | Alta (básico) | Media (estancada) |  En aumento (estándar moderno) |
# | **Comunidad/Ecosistema** | Nativo de Python | Activa pero ralentizada | Muy activa (crece rápido) |
# | **Ideal para** | Scripts simples, aprendizaje | Proyectos medianos | **Proyectos profesionales/producción** |
#
# No obstante, por simplicidad, nosotros vamos a utilizar la gestión que hace Anaconda de los entornos.
#
# Crear y eliminar entornos virtuales con Anaconda, así como instalar o eliminar paquetes es algo que podemos hacer cómodamente a través de la interfaz. Y dándole al botón de `play` podremos lanzar un terminal con el entorno activado.
#
# #### ¿Como usar Entornos Virtuales desde VSCode?
# Seleccionar el entorno con el que trabajamos en VSCode (para poder probar el código desde el entorno) es muy sencillo.
#
#     1. Abrir la paleta de comandos `Ctrl+Mayus+P`
#     2. Escribir: `python select interpeter` y abrirlo
#     3. Seleccionar el entorno que queremos usar.
#
# ![Seleccionar entorno virtual en VSCode](attachment:d8c3e126-bdf7-41a3-be99-9f87112bafcb.jpg)
# Esto hará que el entorno activo se muestre en la parte inferior de nuestro entorno, como puede verse en la imagen. `base (3.14.6)`. Donde, haciendo click, también podremos desplegar el selector de entornos.

# %% [markdown]
# ### 1.5 Jupyter Notebooks
# Jupyter Notebooks es una herramienta que nos permite crear cuadernos de trabajo en formato Markdown con código python embebido. Esto resulta particularmente interesante en entornos educativos y de investigación.
#
# Esta herramienta nos permite, además de incluir bloques de texto en formato Markdown, incluir bloques de texto que se pueden ejecutar aisladamente y en el orden que queramos. Por supuesto, en caso de que haya dependencias de código entre los bloques, estos darán un error.
#
# Hagamos una prueba. Para ejecutar cada bloque, seleccionalo y pulsa `Crtl+Enter`
#
# Ejecuta ahora el siguiente bloque _(Instruccion 1)_:

# %%
#Instruccion 1
print(dato)

# %% [markdown]
# Como ves, la instrucción da un error porque no existe la variable dato, no ha sido creada aún. Ejecutemos el siguiente bloque _(Instruccion 2)_:

# %%
#Instruccion 2
dato = 'Hola Mundo'

# %% [markdown]
# Ahora vuelve a ejecutar el bloque de la _Instruccion 1_, el que contenía la instrucción `print`.

# %% [markdown]
# Ya no muestra ningún error y obtenemos la salida de la ejecución, porque hemos creado antes la variable `dato`. Puede parecer confuso dado que la variable se está creando, aparentemente, una linea después. Aunque esto realmente no es así. Junto a la linea de código, puedes ver unos corchetes con un número `[x]:`, ese número indica el orden de ejecución. Si el número de la línea _Instruccion 2_ es inferior al de la línea _Instruccion 1_ es que se ha ejecutado antes.
#
# Obviamente este es un ejemplo forzado para entender el funcionamiento y, para evitar severos dolores de cabeza, seguiremos un orden en el código. Sin embargo, ejecutar bloques de manera aislada nos permite que, ante errores o cambios, no tengamos que volver a ejecutar todo el código y, si hemos realizado algún cálculo complejo o que consume recursos, no tengamos que volver a ejecutarlo si estamos modificando código posterior.
#
# Podemos lanzar __jupyter notebooks__ tanto desde __Anaconda__ como desde una __terminal__ escribiendo: `jupyter notebook`

# %% [markdown]
# ### Atajos de teclado útiles en Jupyter Notebook
#
# <div style="display: flex; gap: 24px; flex-wrap: wrap;">
#
# <!-- Columna 1: Modo Comando -->
# <div style="flex: 1; min-width: 300px;">
#
# #### Modo Comando (tecla `Esc`)
#
# | Atajo | Acción |
# |---|---|
# | `Enter` | Cambiar a modo Edición |
# | `A` | Insertar celda arriba |
# | `B` | Insertar celda abajo |
# | `D, D` | (dos veces) Eliminar celda actual |
# | `Z` | Deshacer eliminación de celda |
# | `C` | Cortar celda seleccionada |
# | `V` | Pegar celda desde portapapeles |
# | `X` | Cortar y pegar (equivalente a Cortar + Pegar) |
# | `M` | Cambiar a celda de Markdown |
# | `Y` | Cambiar a celda de Código |
# | `L` | Activar/desactivar numeración de líneas |
# | `0, 0` | (dos veces) Reiniciar kernel y limpiar salidas |
# | `I, I` | Interrumpir el kernel (detener ejecución) |
# | `Shift + F` | Buscar y reemplazar en todo el notebook |
# | `Shift + O` | Alternar salida de la celda activa |
# | `Shift + ↑ / ↓` | Seleccionar celda arriba / abajo |
# | `Shift + J / K` | Mover celda abajo / arriba |
# | `Shift + S` | Guardar y crear checkpoint |
#
# </div>
#
# <!-- Columna 2: Modo Edición -->
# <div style="flex: 1; min-width: 300px;">
#
# #### Modo Edición (tecla `Enter`)
#
# | Atajo | Acción |
# |---|---|
# | `Shift + Enter` | Ejecutar celda y mover a la siguiente |
# | `Ctrl + Enter` | Ejecutar celda (sin moverse) |
# | `Alt + Enter` | Ejecutar celda e insertar una nueva abajo |
# | `Ctrl + Shift + -` | Fragmentar celda en el cursor |
# | `Ctrl + Shift + P` | Abrir la paleta de comandos |
# | `Tab` | Autocompletar código / info del objeto |
# | `Shift + Tab` | Mostrar documentación del objeto |
# | `Ctrl + ]` | Indentar línea seleccionada |
# | `Ctrl + [` | Des-indentar línea seleccionada |
# | `Ctrl + /` | Comentar / descomentar línea |
# | `Ctrl + Shift + A` | Autocompletar (agrupar sugerencias) |
# | `Esc` | Volver a modo Comando |
#
# </div>
#
# </div>
#
# #### Consejos rápidos
#
# - **Modo actual**: la barra lateral izquierda cambia de **azul** (edición) a **gris** (comando).
# - **Completar código**: `Tab` abre el autocompletado; `Shift + Tab` muestra la signatura/docstring.
# - **Buscar y reemplazar**: `Shift + F` (modo comando) o `Ctrl + F` (dentro de una celda).

# %% [markdown]
# ### 1.6. Google Colab
# Google Colab es un entorno web de google en el que podemos visualizar y ejecutar los cuadernos de Jupyter. Es una herramienta de gran utilidad sobre todo en esos momentos en los que no disponemos de una máquina configurada o carecemos de recursos suficientes.
#
# ![Google Collab](attachment:20f78bb9-1f77-406e-8640-070671561869.png)
#
# Como en todas las herramientas en la nube, nos encontrarmos con limitaciones en la versión gratuita, pero que deberían ser más que suficientes para llevar a cabo pruebas de concepto.
#
# Atendiendo al FAQ de Google Colab sobre las limitaciones del plan gratuito:
#
# > Colab puede brindar recursos sin costo en parte debido a que tiene límites de uso dinámicos que a veces fluctúan y a que no proporciona recursos garantizados ni ilimitados. Esto significa que los límites de uso generales, además de los períodos de tiempo de espera de inactividad, la vida útil de las VMs, los tipos de GPU disponibles y otros factores, varían con el tiempo. Colab no publica estos límites, en parte porque pueden variar con el tiempo.

# %% [markdown]
# ## 2. Markdown
# Si bien no vamos a dedicar parte de este curso al aprendizaje de __Markdown__ si merece la pena mencionar su importancia a la hora de trabajar con inteligencia artificial. Se trata de un lenguaje de marcas sencillo y ligero. Nos ayudará a estructurar documentos ahorrando tokens para comunicarnos con los agentes de IA, así como para recibir información de su parte.
#
# | Elemento         | Sintaxis                     |
# | ---------------- | ---------------------------- |
# | Título           | `# Título`                   |
# | Negrita          | `**texto**`                  |
# | Cursiva          | `*texto*`                    |
# | Tachado          | `~~texto~~`                  |
# | Enlace           | `[texto](url)`               |
# | Imagen           | `![alt](url)`                |
# | Código inline    | `` `código` ``               |
# | Bloque de código | ```````                      |
# | Lista            | `- elemento` o `1. elemento` |
# | Tabla            | `| Col1 | Col2 |`            |
# | Cita             | `> texto`                    |
# | Línea horizontal | `---`                        |
#
# Además, podemos usar tambien html para documentos más complejos.
#
# Podéis obtener más información de Markdown en: https://www.markdownguide.org/

# %% [markdown]
# ## 3. Sintaxis Básica de Python
# Python es un lenguaje de programación creado por Guido van Rossum y lanzado en 1991. El objetivo era crear un lenguaje de script ligero y con una sintaxis sencilla y fácil de aprender. Para ello, lo primero que desaparece de Python son los delimitadores.
#
# - Los `;` al final de cada sentencia no son necesarios en Python _(se recomienda no hacer uso de ellos)_
# - Las instrucciones compuestas, como clases, métodos, funciones o estructuras de control no hacen uso de `{` y `}`. En su lugar el peso recae sobre una férrea identación. La necesidad de usar tabulación, también contribuye a la legibilidad.
#
# Además, las aplicaciones Python __carecen de método `main`__
#
# Veamos un ejemplo sencillo de código:

# %%
# funcion para sumar dos elementos
def suma(a,b):
    return a+b

resultado = suma(4, 5)

if resultado < 10:
    print(f'{resultado} es menor que 10')
else: 
    print('Numero mayor que 10')
# Out:
# Numero mayor que 10

# %% [markdown]
# ### 3.1. Variables
# Una **variable** es un espacio en memoria que almacena un valor. En Python, no es necesario declarar el tipo de la variable; se infiere automáticamente según el valor que se le asigna.
#
# #### Sintaxis
#
# ```python
# nombre_variable = valor
# ```
#
# #### Reglas para nombrar variables
# - Deben empezar con una letra o guion bajo (`_`)
# - No pueden empezar por un número
# - Solo contienen letras, números y guiones bajos
# - Son **case-sensitive** (`Edad` ≠ `edad`)
# - No pueden ser palabras reservadas (`if`, `for`, `def`, etc.)
# - Convención recomendada: `nombre_con_guion_bajo` (snake_case)

# %%
# Ejemplos de variables
nombre = "Ana"           # string (texto)
edad = 25                # integer (número entero)
altura = 1.68            # float (número decimal)
es_estudiante = True     # boolean (verdadero/falso)

print(nombre)
print(edad)
print(altura)
print(es_estudiante)

# %%
# Asignación múltiple
x, y, z = 10, 20, 30
print(f"x={x}, y={y}, z={z}")

# Asignación a una misma variable
a = b = c = 100
print(f"a={a}, b={b}, c={c}")

# %%
# Función type() para conocer el tipo de una variable
nombre = "Ana"
edad = 25
altura = 1.68
es_estudiante = True

print(type(nombre))   # <class 'str'>
print(type(edad))     # <class 'int'>
print(type(altura))   # <class 'float'>
print(type(es_estudiante))  # <class 'bool'>

# %% [markdown]
# ### 3.2. Tipos de datos básicos
#
# Python tiene varios tipos de datos integrados. Los más importantes son:
#
# | Tipo | Nombre en Python | Ejemplo | Descripción |
# |------|-----------------|---------|-------------|
# | Entero | `int` | `42`, `-7` | Números sin decimales |
# | Decimal | `float` | `3.14`, `-0.5` | Números con decimales |
# | Texto | `str` | `"Hola"`, `'Python'` | Secuencia de caracteres |
# | Booleano | `bool` | `True`, `False` | Valores verdadero/falso |
# | Nulo | `NoneType` | `None` | Ausencia de valor |

# %%
# Enteros (int)
entero_positivo = 10
entero_negativo = -3
print(f"Enteros: {entero_positivo}, {entero_negativo}")

# Decimales (float)
precio = 19.99
pi = 3.14159
print(f"Decimales: {precio}, {pi}")

# Strings (str)
saludo = "Hola Mundo"
curso = 'Programación de IA'
print(f"Strings: {saludo}, {curso}")

# Booleanos (bool)
aprobado = True
suspenso = False
print(f"Booleanos: {aprobado}, {suspenso}")

# %% [markdown]
# ### 3.3. Operadores
#
# Los operadores permiten realizar operaciones sobre variables y valores. En Python se clasifican en:

# %% [markdown]
# #### 3.3.1. Operadores aritméticos
#
# | Operador | Descripción | Ejemplo | Resultado |
# |----------|-------------|---------|-----------|
# | `+` | Suma | `5 + 3` | `8` |
# | `-` | Resta | `10 - 4` | `6` |
# | `*` | Multiplicación | `4 * 2` | `8` |
# | `/` | División (decimal) | `10 / 3` | `3.333...` |
# | `//` | División entera | `10 // 3` | `3` |
# | `%` | Módulo (residuo) | `10 % 3` | `1` |
# | `**` | Potencia | `2 ** 3` | `8` |

# %%
# Operadores aritméticos
a = 15
b = 4

print(f"Suma:         {a} + {b} = {a + b}")
print(f"Resta:        {a} - {b} = {a - b}")
print(f"Multiplicación: {a} * {b} = {a * b}")
print(f"División:     {a} / {b} = {a / b}")
print(f"División ent.: {a} // {b} = {a // b}")
print(f"Módulo:       {a} % {b} = {a % b}")
print(f"Potencia:     {a} ** {b} = {a ** b}")

# %% [markdown]
# #### 3.3.2. Operadores de comparación
#
# Comparan dos valores y devuelven un booleano (`True` o `False`).
#
# | Operador | Descripción | Ejemplo | Resultado |
# |----------|-------------|---------|-----------|
# | `==` | Igual | `5 == 5` | `True` |
# | `!=` | Diferente | `5 != 3` | `True` |
# | `>` | Mayor que | `5 > 3` | `True` |
# | `<` | Menor que | `3 < 5` | `True` |
# | `>=` | Mayor o igual | `5 >= 5` | `True` |
# | `<=` | Menor o igual | `3 <= 5` | `True` |

# %%
# Operadores de comparación
x = 10
y = 20

print(f"{x} == {y}: {x == y}")    # False
print(f"{x} != {y}: {x != y}")    # True
print(f"{x} >  {y}: {x > y}")     # False
print(f"{x} <  {y}: {x < y}")     # True
print(f"{x} >= {x}: {x >= x}")    # True
print(f"{y} <= {y}: {y <= y}")    # True

# %% [markdown]
# #### 3.3.3. Operadores lógicos
#
# Se usan para combinar expresiones booleanas.
#
# | Operador | Descripción | Ejemplo |
# |----------|-------------|---------|
# | `and` | True si AMBOS son True | `True and False` → `False` |
# | `or`  | True si ALGÚN es True  | `True or False` → `True` |
# | `not` | Invierte el valor       | `not True` → `False` |

# %%
# Operadores lógicos
edad = 25
tiene_titulo = True
tiene_experiencia = False

# and: ambas condiciones deben ser True
puede_trabajar = (edad >= 18) and (tiene_titulo)
print(f"Puede trabajar (edad >= 18 Y título): {puede_trabajar}")

# or: basta una condición True
puede_entrar = (edad >= 18) or (tiene_experiencia)
print(f"Puede entrar (edad >= 18 O experiencia): {puede_entrar}")

# not: invierte el valor
no_experiencia = not tiene_experiencia
print(f"No tiene experiencia: {no_experiencia}")

# %% [markdown]
# ### 3.4. Entrada y salida (I/O)
#
# #### 3.4.1. `print()` — Salida de datos
#
# La función `print()` muestra información en pantalla. Se puede usar para mostrar textos, variables o el resultado de expresiones.
#
# #### Formatos de impresión
#
# - **Formato básico**: `print(valor)`
# - **Concatenación**: `print("Texto " + str(variable))`
# - **f-strings** (recomendado): `print(f"Texto {variable}")`

# %%
# print() — Formas de imprimir

# 1. Imprimir texto literal
print("Hola Mundo")

# 2. Imprimir variables
nombre = "Carlos"
edad = 22
print(nombre)
print(edad)

# 3. Imprimir múltiples valores (separados por coma)
print("Nombre:", nombre, "Edad:", edad)

# 4. f-strings (formato recomendado)
print(f"{nombre} tiene {edad} años")

# 5. Concatenación con +
print("Nombre: " + nombre + ", Edad: " + str(edad))

# %% [markdown]
# #### 3.4.2. `input()` — Entrada de datos
#
# La función `input()` permite al usuario escribir datos desde el teclado. **Siempre devuelve un string**, por lo que es necesario convertirlo al tipo deseado.

# %%
# input() — Capturar datos del usuario

# 1. Capturar un texto
nombre_usuario = input("¿Cómo te llamas? ")
print(f"Encantado de conocerte, {nombre_usuario}")

# 2. Capturar un número (recordar convertir!)
# edad = int(input("¿Cuántos años tienes? "))
# print(f"Tienes {edad} años")

# %% [markdown]
# ### 3.5. Conversión de tipos (Casting)
#
# A veces necesitamos cambiar el tipo de una variable. Python proporciona funciones para convertir entre tipos:
#
# | Función | Tipo destino | Ejemplo |
# |---------|-------------|---------|
# | `int()` | Entero | `int("42")` → `42` |
# | `float()` | Decimal | `float("3.14")` → `3.14` |
# | `str()` | Texto | `str(42)` → `"42"` |
# | `bool()` | Booleano | `bool(1)` → `True` |
# | `type()` | — | `type(42)` → `<class 'int'>` |

# %%
# Conversión de tipos

# int() — Convertir a entero
print(int(3.9))       # 3 (trunca, no redondea)
print(int("42"))      # 42

# float() — Convertir a decimal
print(float(5))       # 5.0
print(float("3.14"))  # 3.14

# str() — Convertir a texto
print(str(100))       # "100"
print(str(3.14))      # "3.14"

# bool() — Convertir a booleano
print(bool(1))        # True
print(bool(0))        # False
print(bool("Hola"))   # True
print(bool(""))       # False (cadena vacía)
print(bool([]))       # False (lista vacía)

# %%
# Ejemplo práctico: sumar dos números introducidos por el usuario

# El usuario introduce dos números como texto
num1_str = input("Introduce el primer número: ")
num2_str = input("Introduce el segundo número: ")

# Convertimos a float (para permitir decimales)
num1 = float(num1_str)
num2 = float(num2_str)

# Calculamos la suma
resultado = num1 + num2

# Mostramos el resultado
print(f"El resultado de {num1} + {num2} es {resultado}")

# %% [markdown]
# ### 3.6. Ejercicios propuestos
#
# #### Ejercicio 1.1 — Calculadora de descuentos
# Crea un programa que pida al usuario el precio original de un artículo y el porcentaje de descuento aplicado. El programa debe calcular y mostrar el precio final después del descuento.
#
# Además, el programa debe clasificar el descuento en una de estas categorías:
#
# - Sin descuento: 0 %
# - Oferta: entre 1 % y 15 %
# - Gran oferta: entre 16 % y 40 %
# - Liquidación: más del 40 %
#
# ```python
# # Pista: usa float() para convertir los inputs
# # precio_final = precio_original * (1 - descuento / 100)
# ```
#
# #### Ejercicio 1.2 — Conversor de temperatura
# Crea un programa que pida una temperatura en grados Celsius y la convierta a Fahrenheit usando la fórmula: `F = (C × 9/5) + 32`.
#
# #### Ejercicio 1.3 — Intercambio de variables
# Dadas dos variables `a = 10` y `b = 20`, intercambia sus valores sin usar una tercera variable.
#
# ```python
# # Pista: a, b = b, a
# ```

# %% [markdown]
# ### 3.7. Resumen
#
# | Concepto | Clave |
# |----------|-------|
# | **Variables** | `nombre = valor` — se infiere el tipo automáticamente |
# | **Tipos básicos** | `int`, `float`, `str`, `bool` |
# | **Operadores aritméticos** | `+`, `-`, `*`, `/`, `//`, `%`, `**` |
# | **Operadores de comparación** | `==`, `!=`, `>`, `<`, `>=`, `<=` |
# | **Operadores lógicos** | `and`, `or`, `not` |
# | **Salida** | `print()` con f-strings: `f"{variable}"` |
# | **Entrada** | `input()` — siempre devuelve `str` |
# | **Casting** | `int()`, `float()`, `str()`, `bool()` |

# %% [markdown]
# ## Siguiente tema
#
# A continuación estudiaremos
#
# - **Estructuras de control**: Condicionales e Iterativas
# - **Estructuras de datos**: Listas, diccionarios, conjuntos y tuplas.
# - **Funciones**
# - **Archivos y Módulos**

# %% [markdown]
# ## Documentación oficial
#  - Python: https://docs.python.org/3/

# %% [markdown]
# <div style="text-align: center;">
# <img src="img/by-nc-sa.png" width="200">
#
# <p style="text-align: center;">
# This work is licensed under <a href="https://creativecommons.org/licenses/by-sa/4.0/">Creative Commons Attribution-ShareAlike 4.0 International</a><img src="https://mirrors.creativecommons.org/presskit/icons/cc.svg" alt="" style="max-width: 1em;max-height:1em;margin-left: .2em;"><img src="https://mirrors.creativecommons.org/presskit/icons/by.svg" alt="" style="max-width: 1em;max-height:1em;margin-left: .2em;"><img src="https://mirrors.creativecommons.org/presskit/icons/sa.svg" alt="" style="max-width: 1em;max-height:1em;margin-left: .2em;">
# </p>
# </div>
